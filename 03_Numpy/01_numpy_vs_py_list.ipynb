# %%
import numpy as np
import time

# %%
arr = np.array([1,2,3,4,5])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
#Comparing Numpy And Python_list

# %%
size=1000_000
py_list=list(range(size))
np_arr=np.array(py_list)

# %%
#Python List
start=time.time()
sq_list=[x**2 for x in py_list]
end=time.time()
print(f"python list time = {end-start} seconds")
# Out:
# python list time = 0.3331873416900635 seconds

# %%
#Numpy
start=time.time()
#vectorization
sq_nparr=np_arr ** 2
end=time.time()
print(f"python numpy time = {end-start} seconds")
# Out:
# python numpy time = 0.009117364883422852 seconds

# %%
#Memory
import sys
print(f"Python list size = {sys.getsizeof(py_list)*len(py_list)} bytes")
print(f"Python list size = {np_arr.nbytes} bytes")
# Out:
# Python list size = 8000056000000 bytes
# Python list size = 8000000 bytes
