# %%
# Box plot
"""
A box plot is defined as a statistical visualization that summarizes the distribution of a dataset using five key numbers.
Core Components of a Box Plot :- 
    You are a Principal Developer Experience Engineer, VS Code Performance Specialist, AI Engineer, and Productivity Consultant.

Your task is to perform a complete audit and optimization of my VS Code environment and improve my setup to a score of 90+/100.

My Profile:

Role:

* Full Stack Engineer
* AI/ML Engineer (Learning)

Frontend:

* React
* Vite
* TypeScript
* JavaScript
* Tailwind CSS

Backend:

* Node.js
* Express.js
* REST APIs
* PostgreSQL
* MongoDB

Programming Languages:

* Java
* Python

AI / Data Science:

* NumPy
* Pandas
* Scikit-Learn
* TensorFlow
* PyTorch
* Deep Learning
* Machine Learning
* Data Analysis
* Jupyter Notebooks

Other:

* Git & GitHub
* Docker
* DSA / LeetCode
* System Design
* Interview Preparation

Hardware:

* Windows
* 16GB RAM
* 512GB SSD

Objectives:

1. Analyze all installed extensions.
2. Detect redundant extensions.
3. Detect duplicate functionality.
4. Detect startup bottlenecks.
5. Detect RAM-consuming extensions.
6. Detect unnecessary language packs.
7. Detect unnecessary themes and icon packs.

Optimize for:

* Fast startup (< 5 seconds)
* Low memory usage
* Fast file search
* Fast IntelliSense
* Better GitHub Copilot suggestions
* Better React/Vite development
* Better Node.js development
* Better Java development
* Better Python development
* Better AI/ML workflow
* Better Jupyter workflow
* Better debugging experience

Generate:

A. Extensions To Keep
B. Extensions To Disable
C. Extensions To Uninstall
D. Missing Extensions To Install
E. Optimized settings.json
F. Optimized keybindings.json
G. Optimized Git Settings
H. Optimized Terminal Settings
I. Optimized Copilot Settings
J. Optimized Python Settings
K. Optimized Java Settings
L. Optimized React/Vite Settings
M. Optimized AI/ML Settings
N. Workspace Recommendations
O. Performance Improvements

Special Requirements:

* Keep GitHub Copilot as the primary AI assistant.
* Install GitHub Copilot Chat if not present.
* Remove any extension that duplicates Copilot functionality.
* Keep Jupyter and Data Wrangler for AI/Data Science workflows.
* Recommend only lightweight and high-value extensions.
* Configure VS Code for maximum productivity and minimal distraction.
* Enable best practices for full-stack development and AI engineering.

At the end provide:

1. Current Score (/100)
2. Optimized Score (/100)
3. Estimated Startup Improvement (%)
4. Estimated RAM Savings (MB)
5. Estimated Productivity Increase (%)
6. Exact actions required to reach 90+/100

Do not give generic advice. Analyze the actual installed extensions, settings, and environment, then produce a step-by-step optimization plan.
Minimum: The lowest data point that is not an outlier.
    First Quartile (Q1): The 25th percentile of the dataset.
    Median (Q2): The middle value or 50th percentile.
    Third Quartile (Q3): The 75th percentile of the dataset.
    Maximum: The highest data point that is not an outlier.
"""

"""
Breakdown of Terms:- 
    1 .  (First Quartile): The 25th percentile of the dataset.
    2 .  Q3 (Third Quartile): The 75th percentile of the dataset.
    3 .  IQR (Interquartile Range): The middle 50% of the data, calculated as \(IQR = Q_3 - Q_1\).
"""
"""
    "\"\"\"",
        "Step-by-Step Application",
        "1. Find the Quartiles: Sort your dataset from smallest to largest and find Q1 and Q3.",
        "2. Calculate IQR: Subtract Q1 from Q3.",
        "3. Multiply by 1.5: Calculate the scaling factor (1.5 × IQR).",
        "4. Find Lower Bound: Subtract that value from Q1. Any data point below this result is a lower outlier.",
        "5. Find Upper Bound: Add that value to Q3. Any data point above this result is an upper outlier.",
    "\"\"\"",

"""

# %%
import matplotlib.pyplot as plt

# %%
data = [7,8,5,6,9,4,10,12,15]
plt.boxplot(data)
plt.show()
