# %%
# Matrix plots
# eg :- Heatmaps -> plot rectangular data as color-encoded matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sbs.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot=flights.pivot(index="month" , columns = "year" , values = "passengers")

# %%
sns.heatmap(
    flights_pivot,
    cmap="coolwarm",
    annot=True ,
    fmt = "d"
)
plt.title("Passenger Heatmap")
plt.tight_layout()
