# %%
# Bayes' Theorem 
# P(A|B) = P(B|A) * P(A) / P(B)
# P(A) = Prior probability of A
# P(B) = Prior probability of B
# P(B|A) = Likelihood of B given A
# P(A|B) = Posterior probability of A given B   

'''
def:- bayes_theorem(prior_a, prior_b, likelihood_b_given_a):
    # Calculate the posterior probability using Bayes' Theorem
    posterior_a_given_b = (likelihood_b_given_a * prior_a) / prior_b
    return posterior_a_given_b  
# Example usage
prior_a = 0.3  # Prior probability of A
prior_b = 0.5  # Prior probability of B
likelihood_b_given_a = 0.8  # Likelihood of B given A
posterior_a_given_b = bayes_theorem(prior_a, prior_b, likelihood_b_given_a)
print(f"Posterior probability of A given B: {posterior_a_given_b}")
'''
